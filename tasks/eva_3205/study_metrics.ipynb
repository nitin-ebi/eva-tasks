# %%
import csv
from datetime import datetime

import pandas as pd
import requests
import seaborn
import matplotlib.pyplot as plt

from ete3 import NCBITaxa
from ebi_eva_internal_pyutils.metadata_utils import get_metadata_connection_handle
from ebi_eva_internal_pyutils.pg_utils import get_all_results_for_query
from fontTools.merge.util import first

ete_db = NCBITaxa()

seaborn.set_style('white')


# File containing password not committed to the repository
private_config_xml_file = 'maven_settings.xml'
query = '''SELECT project_accession  FROM evapro.project WHERE ena_status=4 AND eva_status=1;'''
with get_metadata_connection_handle('production_processing', private_config_xml_file) as db_conn:
    all_project_accessions = [p for p, in get_all_results_for_query(db_conn, query)]
all_project_accessions.remove('PRJEBZ0001')
all_project_accessions.remove('PRJX00001')
# Out:
# /Users/tcezard/PycharmProjects/eva-tasks/venv/lib/python3.9/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
# Generating the TSV file involved querying the accessioning warehouse for dbsnp study name and taxonomy and
# listing the unmapped studies in the filesystem.
with open('dated_studies.tsv') as open_input:
    reader = csv.DictReader(open_input, delimiter='\t')
    required_ranks = ['superkingdom', 'kingdom', 'class', 'order', 'species']
    all_records = []
    all_project_loaded = set()
    for rec in reader:
        lineage = ete_db.get_lineage(int(rec.get('taxid')))
        # Get the rank of each taxonomy ids
        ranks = ete_db.get_rank(lineage)
        # Get the taxonomy of the required ranks
        for required_rank in required_ranks:
            taxid_for_rank = [i for i in ranks if ranks[i] == required_rank]
            if taxid_for_rank:
                # Get the scientific names of the rank
                sci_name_of_required_rank = ete_db.get_taxid_translator(taxid_for_rank)[taxid_for_rank[0]]
            rec[required_rank] = sci_name_of_required_rank
        all_records.append(rec)
        all_project_loaded.add(rec['project'])

    missing_projects = set(all_project_accessions).difference(all_project_loaded)
    if missing_projects:
        missing_projects_str = ', '.join([f"'{p}'" for p in missing_projects])
        print('Retrieve the missing project dates and taxid from ERAPRO using the following query:')
        print(f"SELECT PROJECT_ID, TAX_ID, substr(TO_CHAR(FIRST_CREATED, 'YYYY-MM'), 0, 7) AS D "
              f"FROM era.project "
              f"WHERE PROJECT_ID IN ({missing_projects_str});")
    extra_projects = all_project_loaded.difference(set(all_project_accessions))
    if extra_projects:
        print(f'{len(extra_projects)} projects have been loaded but are not in the EVA database:')
        print(extra_projects)
# Out:
# /Users/tcezard/PycharmProjects/eva-tasks/venv/lib/python3.9/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 30523 was translated into 30522
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))

# %%
df = pd.DataFrame.from_dict(all_records)
df['date'] = pd.to_datetime(df['date'], format="%Y-%m")
# Change the non Eukaryota to use the superkingdom value instead to limit variability
df['label'] = df['class']
df.loc[df.superkingdom != 'Eukaryota', 'label'] = 'Non-Eukaryota'
# Filter out anything that is not Eukaryota
# df = df[df.superkingdom == 'Eukaryota']
# Change the label of Human to separate them from other mammals
df.loc[df.species == 'Homo sapiens', 'label'] = 'Homo sapiens'
# Change all the label not in the list bellow to others
accepted_classes = {'Aves': 'Birds','Insecta':'Insects','Actinopteri': 'Fish','Mammalia': 'Mammals','Magnoliopsida': 'Flowering plants', 'Non-Eukaryota': 'Non-Eukaryotes', 'Homo sapiens': 'Human'}
# Check ~ which somehow means "NOT IN" in pandas
df.loc[~df['label'].isin(accepted_classes), 'label'] = 'Other eukaryotes'
df = df.replace({'label': accepted_classes})

# %%
def aggregate_first_seen(df):
    # Group by taxid to find the most ancient occurrence and drop all the other rows
    # Then group by label and date to count the number of new taxid discovered each month
    # unstack and restack to fill in every combination label/date with 0 if it did not exist
    first_seen_taxid = df.groupby('taxid').apply(lambda g: g.nsmallest(1, "date")).reset_index(drop=True)\
                         .groupby(['label', 'date'])[["taxid"]].count().unstack(fill_value=0).stack().reset_index()
    # Then calculate the cumulative number of species for each label
    first_seen_taxid['Number of species'] = first_seen_taxid.groupby(['label'])['taxid'].cumsum()
    return first_seen_taxid.reset_index()

def aggregate_count_studies(df):
    # Group by label and date to count the number of studies added each month
    # unstack and restack to fill in every combination label/date with 0 if it did not exist
    count_studies = df.groupby(['label', 'date'])[["taxid"]].count().unstack(fill_value=0).stack().reset_index()
    # Then calculate the cumulative number of studies for each label
    count_studies['Number of studies'] = count_studies.groupby(['label'])['taxid'].cumsum()
    return count_studies.reset_index()

def plot_taxid_and_studies(first_seen_taxid, count_studies):
    fig, ax = plt.subplot_mosaic([['left', 'right']], layout='constrained')
    g1 = seaborn.lineplot(data=first_seen_taxid, x='date', y='Number of species', hue='label', ax=ax['left'])
    g1.tick_params(axis='x', rotation=45)
    g1.get_legend().remove()
    g1.grid(False)
    g2 = seaborn.lineplot(data=count_studies, x='date', y='Number of studies', hue='label', ax=ax['right'])
    g2.tick_params(axis='x', rotation=45)
    g2.get_legend().remove()
    g2.grid(False)
    handles, labels = g2.get_legend_handles_labels()
    fig.legend(handles=handles, labels=labels, loc='outside left center', ncol=1, bbox_to_anchor=(1, 0.5))

def plot_taxid(first_seen_taxid, linewidth=1, font_scale=1):
    seaborn.set(font_scale=font_scale)
    seaborn.set_style('white')
    g1 = seaborn.lineplot(data=first_seen_taxid, x='date', y='Number of species', hue='label', linewidth=linewidth)
    g1.tick_params(axis='x', rotation=45)
    handles, labels = g1.get_legend_handles_labels()
    g1.legend(handles=handles[0:], labels=labels[0:])
    g1.grid(False)

def plot_studies(count_studies):
    g2 = seaborn.lineplot(data=count_studies, x='date', y='Number of studies', hue='label')
    g2.tick_params(axis='x', rotation=45)
    g2.grid(False)

# %% [markdown]
# ## Show the number of species and studies added to EVA over time

# %%
df['label'] = df['class']
df.loc[df.superkingdom != 'Eukaryota', 'label'] = 'Others'

# Change all the label not in the list bellow to others
accepted_classes = {'Aves': 'Animals','Insecta':'Animals','Actinopteri': 'Animals','Mammalia': 'Animals','Magnoliopsida': 'Flowering plants'}

# Check ~ which somehow means "NOT IN" in pandas
df.loc[~df['label'].isin(accepted_classes), 'label'] = 'Others'
df = df.replace({'label': accepted_classes})

# Change the label of Human to separate them from other mammals
df.loc[df.species == 'Homo sapiens', 'label'] = 'Human'
# df = df[df.label != 'Others']
# df = df[df.label != 'Human']

first_seen_taxid = aggregate_first_seen(df)
count_studies = aggregate_count_studies(df)
# to_replace_class = ['Birds', 'Insects', 'Fish', 'Mammals','Non-Eukaryotes','Human']
# first_seen_taxid.loc[first_seen_taxid['label'].isin(to_replace_class), 'class'] = 'Others '
plot_taxid(first_seen_taxid, font_scale=1.5, linewidth=2)
# plot_studies(count_studies)
# plot_taxid_and_studies(first_seen_taxid, count_studies)

# %%
data=df.groupby(['taxid', 'label']).count().reset_index().groupby(['label'])[['taxid']].count().sort_values(by='taxid').reset_index()
data
seaborn.set_style("whitegrid") # Set style for chart
plt.figure(figsize=(6,6)) # Set figure size
plt.pie(data['taxid'], labels=data['label'], autopct='%1.0f%%',  pctdistance=.8, textprops={'fontsize': 20}) # Create pie chart
plt.show() # Show chart

# %%
df['label'] = df['class']
df.loc[df.superkingdom != 'Eukaryota', 'label'] = 'Others'

# Change all the label not in the list bellow to others
accepted_classes = {'Aves': 'Birds','Insecta':'Insects','Actinopteri': 'Fish','Mammalia': 'Mammals','Magnoliopsida': 'Flowering plants', 'Non-Eukaryota': 'Non-Eukaryotes', 'Homo sapiens': 'Human'}
# Check ~ which somehow means "NOT IN" in pandas
df.loc[~df['label'].isin(accepted_classes), 'label'] = 'Others'
df = df.replace({'label': accepted_classes})

# Change the label of Human to separate them from other mammals
df.loc[df.species == 'Homo sapiens', 'label'] = 'Human'
# df = df[df.label != 'Others']
# df = df[df.label != 'Human']

data = df.groupby(['label'])[['project']].count().sort_values(by='project').reset_index()
seaborn.set_style("whitegrid") # Set style for chart
plt.figure(figsize=(6,6)) # Set figure size
plt.pie(data['project'], labels=data['label'], autopct='%1.0f%%',  pctdistance=.8, textprops={'fontsize': 20}) # Create pie chart
# plt.pie(sizes, labels=sizes.index, autopct='%1.0f%%',  pctdistance=.8, textprops={'fontsize': 20}) # Create pie chart
plt.show() # Show chart

# %%
new_species_in_2020 = sum(first_seen_taxid[(first_seen_taxid['date'] > datetime(year=2020, month=1, day=1)) & (first_seen_taxid['date'] < datetime(year=2021, month=1, day=1))]['taxid'])
new_species_in_2021 = sum(first_seen_taxid[(first_seen_taxid['date'] > datetime(year=2021, month=1, day=1)) & (first_seen_taxid['date'] < datetime(year=2022, month=1, day=1))]['taxid'])
new_species_in_2022 = sum(first_seen_taxid[(first_seen_taxid['date'] > datetime(year=2022, month=1, day=1)) & (first_seen_taxid['date'] < datetime(year=2023, month=1, day=1))]['taxid'])
new_species_in_2023 = sum(first_seen_taxid[(first_seen_taxid['date'] > datetime(year=2023, month=1, day=1)) & (first_seen_taxid['date'] < datetime(year=2024, month=1, day=1))]['taxid'])
new_species_in_2024 = sum(first_seen_taxid[(first_seen_taxid['date'] > datetime(year=2024, month=1, day=1)) & (first_seen_taxid['date'] < datetime(year=2025, month=1, day=1))]['taxid'])
print(f"In 2020: {new_species_in_2020} New species were added.")
print(f"In 2021: {new_species_in_2021} New species were added.")
print(f"In 2022: {new_species_in_2022} New species were added.")
print(f"In 2023: {new_species_in_2023} New species were added.")
print(f"In 2024: {new_species_in_2024} New species were added.")
# Out:
# In 2020: 18 New species were added.
# In 2021: 9 New species were added.
# In 2022: 15 New species were added.
# In 2023: 25 New species were added.
# In 2024: 22 New species were added.

# %% [markdown]
# ## Show the number of species and studies added to EVA over time (main Eukaryotes)

# %%
accepted_classes = ['Birds', 'Insects', 'Fish', 'Mammals', 'Flowering plants']
plot_taxid_and_studies(first_seen_taxid[first_seen_taxid['class'].isin(accepted_classes)], count_studies[count_studies['class'].isin(accepted_classes)])

# %% [markdown]
# ## Show the number of species and studies added to EVA over time (excluding DBSNP studies)

# %%
first_seen_taxid = aggregate_first_seen(df[df['study_type'] == 'EVA study'])
count_studies = aggregate_count_studies(df[df['study_type'] == 'EVA study'])
plot_taxid_and_studies(first_seen_taxid, count_studies)

# %% [markdown]
# ## Show the number of species and studies added to EVA over time (excluding DBSNP studies and main Eukaryotes only)

# %%
plot_taxid_and_studies(first_seen_taxid[first_seen_taxid['class'].isin(accepted_classes)], count_studies[count_studies['class'].isin(accepted_classes)])

# %%
studies_per_month = df.groupby(['date'])[["taxid"]].count().reset_index()
studies_per_month
# Out:
#           date  taxid
# 0   2013-05-01      1
# 1   2013-06-01      2
# 2   2013-07-01      1
# 3   2014-02-01      1
# 4   2014-03-01      2
# ..         ...    ...
# 119 2024-07-01      7
# 120 2024-08-01      8
# 121 2024-09-01     13
# 122 2024-10-01      7
# 123 2024-11-01     16
#
# [124 rows x 2 columns]

# %% [markdown]
# # Release data analysis

# %%
import requests
release_api = 'https://www.ebi.ac.uk/eva/webservices/release/v1/info/latest'
response = requests.get(release_api)
response.raise_for_status()
latest_release = response.json()
release_version = latest_release.get('releaseVersion')
per_species_release_api = 'https://www.ebi.ac.uk/eva/webservices/release/v2/stats/per-species?releaseVersion=' + str(release_version)
response = requests.get(per_species_release_api)
response.raise_for_status()
release_count_per_species = response.json()
release_records = []
for release_count in release_count_per_species:
    record = {'taxid': release_count.get('taxonomyId'), 'rsid': release_count.get('currentRs')}

    lineage = ete_db.get_lineage(int(release_count.get('taxonomyId')))
    # Get the rank of each taxonomy ids
    ranks = ete_db.get_rank(lineage)
    # Get the taxonomy of the required ranks
    for required_rank in required_ranks:
        taxid_for_rank = [i for i in ranks if ranks[i] == required_rank]
        if taxid_for_rank:
            # Get the scientific names of the rank
            sci_name_of_required_rank = ete_db.get_taxid_translator(taxid_for_rank)[taxid_for_rank[0]]
        record[required_rank] = sci_name_of_required_rank
    release_records.append(record)
release_records
# Out:
# /Users/tcezard/PycharmProjects/eva-tasks/venv/lib/python3.9/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 469586 was translated into 818
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /Users/tcezard/PycharmProjects/eva-tasks/venv/lib/python3.9/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 563191 was translated into 187327
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /Users/tcezard/PycharmProjects/eva-tasks/venv/lib/python3.9/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 469587 was translated into 817
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# [{'taxid': 330879,
#   'rsid': 114617,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Fungi',
#   'class': 'Eurotiomycetes',
#   'order': 'Eurotiales',
#   'species': 'Aspergillus fumigatus'},
#  {'taxid': 3847,
#   'rsid': 20017684,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Viridiplantae',
#   'class': 'Magnoliopsida',
#   'order': 'Fabales',
#   'species': 'Glycine max'},
#  {'taxid': 8022,
#   'rsid': 34776,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Actinopteri',
#   'order': 'Salmoniformes',
#   'species': 'Oncorhynchus mykiss'},
#  {'taxid': 4577,
#   'rsid': 79750539,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Viridiplantae',
#   'class': 'Magnoliopsida',
#   'order': 'Poales',
#   'species': 'Zea mays'},
#  {'taxid': 7070,
#   'rsid': 233,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Insecta',
#   'order': 'Coleoptera',
#   'species': 'Tribolium castaneum'},
#  {'taxid': 105023,
#   'rsid': 287,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Actinopteri',
#   'order': 'Cyprinodontiformes',
#   'species': 'Nothobranchius furzeri'},
#  {'taxid': 9593,
#   'rsid': 4,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Mammalia',
#   'order': 'Primates',
#   'species': 'Gorilla gorilla'},
#  {'taxid': 3880,
#   'rsid': 16,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Viridiplantae',
#   'class': 'Magnoliopsida',
#   'order': 'Fabales',
#   'species': 'Medicago truncatula'},
#  {'taxid': 93934,
#   'rsid': 8665,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Aves',
#   'order': 'Galliformes',
#   'species': 'Coturnix japonica'},
#  {'taxid': 79684,
#   'rsid': 8166,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Mammalia',
#   'order': 'Rodentia',
#   'species': 'Microtus ochrogaster'},
#  {'taxid': 5833,
#   'rsid': 290587,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Eukaryota',
#   'class': 'Aconoidasida',
#   'order': 'Haemosporida',
#   'species': 'Plasmodium falciparum'},
#  {'taxid': 8030,
#   'rsid': 19688095,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Actinopteri',
#   'order': 'Salmoniformes',
#   'species': 'Salmo salar'},
#  {'taxid': 9157,
#   'rsid': 498442,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Aves',
#   'order': 'Passeriformes',
#   'species': 'Parus major'},
#  {'taxid': 9913,
#   'rsid': 110140039,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Mammalia',
#   'order': 'Artiodactyla',
#   'species': 'Bos taurus'},
#  {'taxid': 9915,
#   'rsid': 20344385,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Mammalia',
#   'order': 'Artiodactyla',
#   'species': 'Bos indicus'},
#  {'taxid': 9925,
#   'rsid': 36713165,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Mammalia',
#   'order': 'Artiodactyla',
#   'species': 'Capra hircus'},
#  {'taxid': 59894,
#   'rsid': 37728,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Aves',
#   'order': 'Passeriformes',
#   'species': 'Ficedula albicollis'},
#  {'taxid': 9986,
#   'rsid': 81104,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Mammalia',
#   'order': 'Lagomorpha',
#   'species': 'Oryctolagus cuniculus'},
#  {'taxid': 4558,
#   'rsid': 55754150,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Viridiplantae',
#   'class': 'Magnoliopsida',
#   'order': 'Poales',
#   'species': 'Sorghum bicolor'},
#  {'taxid': 74426,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Coriobacteriia',
#   'order': 'Coriobacteriales',
#   'species': 'Collinsella aerofaciens'},
#  {'taxid': 128810,
#   'rsid': 0,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Viridiplantae',
#   'class': 'Magnoliopsida',
#   'order': 'Poales',
#   'species': 'Saccharum hybrid cultivar'},
#  {'taxid': 9541,
#   'rsid': 1651397,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Mammalia',
#   'order': 'Primates',
#   'species': 'Macaca fascicularis'},
#  {'taxid': 4565,
#   'rsid': 292182658,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Viridiplantae',
#   'class': 'Magnoliopsida',
#   'order': 'Poales',
#   'species': 'Triticum aestivum'},
#  {'taxid': 46689,
#   'rsid': 0,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Aves',
#   'order': 'Passeriformes',
#   'species': 'Ficedula hypoleuca'},
#  {'taxid': 563193,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Bacteroidia',
#   'order': 'Bacteroidales',
#   'species': 'Parabacteroides sp. D13'},
#  {'taxid': 1917,
#   'rsid': 6716,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Actinomycetes',
#   'order': 'Streptomycetales',
#   'species': 'Streptomyces macromomyceticus'},
#  {'taxid': 469586,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Bacteroidia',
#   'order': 'Bacteroidales',
#   'species': 'Bacteroides thetaiotaomicron'},
#  {'taxid': 74940,
#   'rsid': 0,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Actinopteri',
#   'order': 'Salmoniformes',
#   'species': 'Oncorhynchus tshawytscha'},
#  {'taxid': 8307,
#   'rsid': 598720662,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Amphibia',
#   'order': 'Caudata',
#   'species': "Ambystoma 'unisexual hybrid complex'"},
#  {'taxid': 573,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Gammaproteobacteria',
#   'order': 'Enterobacterales',
#   'species': 'Klebsiella pneumoniae'},
#  {'taxid': 72036,
#   'rsid': 12,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Hexanauplia',
#   'order': 'Siphonostomatoida',
#   'species': 'Lepeophtheirus salmonis'},
#  {'taxid': 79200,
#   'rsid': 1378278,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Viridiplantae',
#   'class': 'Magnoliopsida',
#   'order': 'Apiales',
#   'species': 'Daucus carota'},
#  {'taxid': 216816,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Actinomycetes',
#   'order': 'Bifidobacteriales',
#   'species': 'Bifidobacterium longum'},
#  {'taxid': 100886,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Erysipelotrichia',
#   'order': 'Erysipelotrichales',
#   'species': 'Catenibacterium mitsuokai'},
#  {'taxid': 3483,
#   'rsid': 1816,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Viridiplantae',
#   'class': 'Magnoliopsida',
#   'order': 'Rosales',
#   'species': 'Cannabis sativa'},
#  {'taxid': 7994,
#   'rsid': 0,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Actinopteri',
#   'order': 'Characiformes',
#   'species': 'Astyanax mexicanus'},
#  {'taxid': 154288,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Erysipelotrichia',
#   'order': 'Erysipelotrichales',
#   'species': 'Turicibacter sanguinis'},
#  {'taxid': 310298,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Bacteroidia',
#   'order': 'Bacteroidales',
#   'species': 'Phocaeicola coprocola'},
#  {'taxid': 40520,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Clostridia',
#   'order': 'Eubacteriales',
#   'species': 'Blautia obeum'},
#  {'taxid': 8845,
#   'rsid': 6,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Aves',
#   'order': 'Anseriformes',
#   'species': 'Anser cygnoides'},
#  {'taxid': 34274,
#   'rsid': 0,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Viridiplantae',
#   'class': 'Magnoliopsida',
#   'order': 'Malvales',
#   'species': 'Gossypium herbaceum'},
#  {'taxid': 310297,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Bacteroidia',
#   'order': 'Bacteroidales',
#   'species': 'Phocaeicola plebeius'},
#  {'taxid': 261299,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Clostridia',
#   'order': 'Eubacteriales',
#   'species': 'Intestinibacter bartlettii'},
#  {'taxid': 850,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Fusobacteriia',
#   'order': 'Fusobacteriales',
#   'species': 'Fusobacterium mortiferum'},
#  {'taxid': 39638,
#   'rsid': 0,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Aves',
#   'order': 'Passeriformes',
#   'species': 'Agelaius phoeniceus'},
#  {'taxid': 328814,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Bacteroidia',
#   'order': 'Bacteroidales',
#   'species': 'Alistipes shahii'},
#  {'taxid': 821,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Bacteroidia',
#   'order': 'Bacteroidales',
#   'species': 'Phocaeicola vulgatus'},
#  {'taxid': 246787,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Bacteroidia',
#   'order': 'Bacteroidales',
#   'species': 'Bacteroides cellulosilyticus'},
#  {'taxid': 10096,
#   'rsid': 0,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Mammalia',
#   'order': 'Rodentia',
#   'species': 'Mus spretus'},
#  {'taxid': 3635,
#   'rsid': 85757,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Viridiplantae',
#   'class': 'Magnoliopsida',
#   'order': 'Malvales',
#   'species': 'Gossypium hirsutum'},
#  {'taxid': 61853,
#   'rsid': 1114820,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Mammalia',
#   'order': 'Primates',
#   'species': 'Nomascus leucogenys'},
#  {'taxid': 40214,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Gammaproteobacteria',
#   'order': 'Moraxellales',
#   'species': 'Acinetobacter johnsonii'},
#  {'taxid': 9796,
#   'rsid': 41619391,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Mammalia',
#   'order': 'Perissodactyla',
#   'species': 'Equus caballus'},
#  {'taxid': 9483,
#   'rsid': 17027504,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Mammalia',
#   'order': 'Primates',
#   'species': 'Callithrix jacchus'},
#  {'taxid': 29348,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Erysipelotrichia',
#   'order': 'Erysipelotrichales',
#   'species': '[Clostridium] spiroforme'},
#  {'taxid': 10090,
#   'rsid': 125660466,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Mammalia',
#   'order': 'Rodentia',
#   'species': 'Mus musculus'},
#  {'taxid': 5855,
#   'rsid': 1979535,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Eukaryota',
#   'class': 'Aconoidasida',
#   'order': 'Haemosporida',
#   'species': 'Plasmodium vivax'},
#  {'taxid': 33043,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Clostridia',
#   'order': 'Eubacteriales',
#   'species': 'Coprococcus eutactus'},
#  {'taxid': 5039,
#   'rsid': 0,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Fungi',
#   'class': 'Eurotiomycetes',
#   'order': 'Onygenales',
#   'species': 'Blastomyces dermatitidis'},
#  {'taxid': 1318,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Bacilli',
#   'order': 'Lactobacillales',
#   'species': 'Streptococcus parasanguinis'},
#  {'taxid': 3981,
#   'rsid': 669,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Viridiplantae',
#   'class': 'Magnoliopsida',
#   'order': 'Malpighiales',
#   'species': 'Hevea brasiliensis'},
#  {'taxid': 29073,
#   'rsid': 0,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Mammalia',
#   'order': 'Carnivora',
#   'species': 'Ursus maritimus'},
#  {'taxid': 411486,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Clostridia',
#   'order': 'Eubacteriales',
#   'species': 'Clostridium sp. M62/1'},
#  {'taxid': 36855,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Alphaproteobacteria',
#   'order': 'Hyphomicrobiales',
#   'species': 'Brucella canis'},
#  {'taxid': 2702,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Actinomycetes',
#   'order': 'Bifidobacteriales',
#   'species': 'Gardnerella vaginalis'},
#  {'taxid': 106654,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Gammaproteobacteria',
#   'order': 'Moraxellales',
#   'species': 'Acinetobacter nosocomialis'},
#  {'taxid': 360807,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Clostridia',
#   'order': 'Eubacteriales',
#   'species': 'Roseburia inulinivorans'},
#  {'taxid': 4006,
#   'rsid': 3420724,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Viridiplantae',
#   'class': 'Magnoliopsida',
#   'order': 'Malpighiales',
#   'species': 'Linum usitatissimum'},
#  {'taxid': 552396,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Erysipelotrichia',
#   'order': 'Erysipelotrichales',
#   'species': 'Erysipelotrichaceae bacterium 5_2_54FAA'},
#  {'taxid': 7719,
#   'rsid': 23,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Ascidiacea',
#   'order': 'Phlebobranchia',
#   'species': 'Ciona intestinalis'},
#  {'taxid': 334908,
#   'rsid': 6457,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Actinopteri',
#   'order': 'Actinopteri',
#   'species': 'Larimichthys polyactis'},
#  {'taxid': 1681,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Actinomycetes',
#   'order': 'Bifidobacteriales',
#   'species': 'Bifidobacterium bifidum'},
#  {'taxid': 4529,
#   'rsid': 13539446,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Viridiplantae',
#   'class': 'Magnoliopsida',
#   'order': 'Poales',
#   'species': 'Oryza rufipogon'},
#  {'taxid': 40518,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Clostridia',
#   'order': 'Eubacteriales',
#   'species': 'Ruminococcus bromii'},
#  {'taxid': 39486,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Clostridia',
#   'order': 'Eubacteriales',
#   'species': 'Dorea formicigenerans'},
#  {'taxid': 2173,
#   'rsid': 0,
#   'superkingdom': 'Archaea',
#   'kingdom': 'Archaea',
#   'class': 'Methanobacteria',
#   'order': 'Methanobacteriales',
#   'species': 'Methanobrevibacter smithii'},
#  {'taxid': 46259,
#   'rsid': 3597,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Actinopteri',
#   'order': 'Actinopteri',
#   'species': 'Morone chrysops'},
#  {'taxid': 245014,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Clostridia',
#   'order': 'Eubacteriales',
#   'species': 'butyrate-producing bacterium SS3/4'},
#  {'taxid': 4236,
#   'rsid': 293094,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Viridiplantae',
#   'class': 'Magnoliopsida',
#   'order': 'Asterales',
#   'species': 'Lactuca sativa'},
#  {'taxid': 99883,
#   'rsid': 0,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Actinopteri',
#   'order': 'Tetraodontiformes',
#   'species': 'Tetraodon nigroviridis'},
#  {'taxid': 4081,
#   'rsid': 7808,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Viridiplantae',
#   'class': 'Magnoliopsida',
#   'order': 'Solanales',
#   'species': 'Solanum lycopersicum'},
#  {'taxid': 4072,
#   'rsid': 2521422,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Viridiplantae',
#   'class': 'Magnoliopsida',
#   'order': 'Solanales',
#   'species': 'Capsicum annuum'},
#  {'taxid': 563191,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Negativicutes',
#   'order': 'Acidaminococcales',
#   'species': 'Acidaminococcus intestini'},
#  {'taxid': 3708,
#   'rsid': 267652,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Viridiplantae',
#   'class': 'Magnoliopsida',
#   'order': 'Brassicales',
#   'species': 'Brassica napus'},
#  {'taxid': 10116,
#   'rsid': 9811964,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Mammalia',
#   'order': 'Rodentia',
#   'species': 'Rattus norvegicus'},
#  {'taxid': 42345,
#   'rsid': 0,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Viridiplantae',
#   'class': 'Magnoliopsida',
#   'order': 'Arecales',
#   'species': 'Phoenix dactylifera'},
#  {'taxid': 3694,
#   'rsid': 8149691,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Viridiplantae',
#   'class': 'Magnoliopsida',
#   'order': 'Malpighiales',
#   'species': 'Populus trichocarpa'},
#  {'taxid': 5861,
#   'rsid': 0,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Eukaryota',
#   'class': 'Aconoidasida',
#   'order': 'Haemosporida',
#   'species': 'Plasmodium yoelii'},
#  {'taxid': 62324,
#   'rsid': 11800324,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Insecta',
#   'order': 'Diptera',
#   'species': 'Anopheles funestus'},
#  {'taxid': 8839,
#   'rsid': 59435171,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Aves',
#   'order': 'Anseriformes',
#   'species': 'Anas platyrhynchos'},
#  {'taxid': 29760,
#   'rsid': 425228,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Viridiplantae',
#   'class': 'Magnoliopsida',
#   'order': 'Vitales',
#   'species': 'Vitis vinifera'},
#  {'taxid': 9258,
#   'rsid': 0,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Mammalia',
#   'order': 'Monotremata',
#   'species': 'Ornithorhynchus anatinus'},
#  {'taxid': 9031,
#   'rsid': 27372389,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Aves',
#   'order': 'Galliformes',
#   'species': 'Gallus gallus'},
#  {'taxid': 8840,
#   'rsid': 337418,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Aves',
#   'order': 'Anseriformes',
#   'species': 'Anas platyrhynchos'},
#  {'taxid': 34506,
#   'rsid': 196381,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Chromadorea',
#   'order': 'Rhabditida',
#   'species': 'Strongyloides ratti'},
#  {'taxid': 6239,
#   'rsid': 0,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Chromadorea',
#   'order': 'Rhabditida',
#   'species': 'Caenorhabditis elegans'},
#  {'taxid': 166486,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Clostridia',
#   'order': 'Eubacteriales',
#   'species': 'Roseburia intestinalis'},
#  {'taxid': 1352,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Bacilli',
#   'order': 'Lactobacillales',
#   'species': 'Enterococcus faecium'},
#  {'taxid': 4896,
#   'rsid': 254349,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Fungi',
#   'class': 'Schizosaccharomycetes',
#   'order': 'Schizosaccharomycetales',
#   'species': 'Schizosaccharomyces pombe'},
#  {'taxid': 6728,
#   'rsid': 0,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Malacostraca',
#   'order': 'Decapoda',
#   'species': 'Procambarus clarkii'},
#  {'taxid': 236,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Alphaproteobacteria',
#   'order': 'Hyphomicrobiales',
#   'species': 'Brucella ovis'},
#  {'taxid': 4530,
#   'rsid': 67584308,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Viridiplantae',
#   'class': 'Magnoliopsida',
#   'order': 'Poales',
#   'species': 'Oryza sativa'},
#  {'taxid': 657323,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Clostridia',
#   'order': 'Eubacteriales',
#   'species': 'Ruminococcus sp. SR1/5'},
#  {'taxid': 1623,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Bacilli',
#   'order': 'Lactobacillales',
#   'species': 'Ligilactobacillus ruminis'},
#  {'taxid': 8128,
#   'rsid': 4882431,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Actinopteri',
#   'order': 'Cichliformes',
#   'species': 'Oreochromis niloticus'},
#  {'taxid': 29361,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Clostridia',
#   'order': 'Eubacteriales',
#   'species': 'Tyzzerella nexilis'},
#  {'taxid': 3885,
#   'rsid': 41626278,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Viridiplantae',
#   'class': 'Magnoliopsida',
#   'order': 'Fabales',
#   'species': 'Phaseolus vulgaris'},
#  {'taxid': 3827,
#   'rsid': 436114,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Viridiplantae',
#   'class': 'Magnoliopsida',
#   'order': 'Fabales',
#   'species': 'Cicer arietinum'},
#  {'taxid': 457421,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Clostridia',
#   'order': 'Eubacteriales',
#   'species': 'Clostridiales bacterium 1_7_47FAA'},
#  {'taxid': 208479,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Clostridia',
#   'order': 'Eubacteriales',
#   'species': 'Enterocloster bolteae'},
#  {'taxid': 9544,
#   'rsid': 52985919,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Mammalia',
#   'order': 'Primates',
#   'species': 'Macaca mulatta'},
#  {'taxid': 820,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Bacteroidia',
#   'order': 'Bacteroidales',
#   'species': 'Bacteroides uniformis'},
#  {'taxid': 319058,
#   'rsid': 18952944,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Actinopteri',
#   'order': 'Cichliformes',
#   'species': 'Cichliformes'},
#  {'taxid': 386414,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Bacteroidia',
#   'order': 'Bacteroidales',
#   'species': 'Prevotella timonensis'},
#  {'taxid': 3884,
#   'rsid': 8390048,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Viridiplantae',
#   'class': 'Magnoliopsida',
#   'order': 'Fabales',
#   'species': 'Phaseolus lunatus'},
#  {'taxid': 3821,
#   'rsid': 734810,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Viridiplantae',
#   'class': 'Magnoliopsida',
#   'order': 'Fabales',
#   'species': 'Cajanus cajan'},
#  {'taxid': 39946,
#   'rsid': 1449479,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Viridiplantae',
#   'class': 'Magnoliopsida',
#   'order': 'Poales',
#   'species': 'Oryza sativa'},
#  {'taxid': 39947,
#   'rsid': 35977,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Viridiplantae',
#   'class': 'Magnoliopsida',
#   'order': 'Poales',
#   'species': 'Oryza sativa'},
#  {'taxid': 28026,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Actinomycetes',
#   'order': 'Bifidobacteriales',
#   'species': 'Bifidobacterium pseudocatenulatum'},
#  {'taxid': 39496,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Clostridia',
#   'order': 'Eubacteriales',
#   'species': 'Eubacterium ventriosum'},
#  {'taxid': 59729,
#   'rsid': 1658611,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Aves',
#   'order': 'Passeriformes',
#   'species': 'Taeniopygia guttata'},
#  {'taxid': 30538,
#   'rsid': 79346,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Mammalia',
#   'order': 'Artiodactyla',
#   'species': 'Vicugna pacos'},
#  {'taxid': 847,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Betaproteobacteria',
#   'order': 'Burkholderiales',
#   'species': 'Oxalobacter formigenes'},
#  {'taxid': 9903,
#   'rsid': 132119556,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Mammalia',
#   'order': 'Artiodactyla',
#   'species': 'Artiodactyla'},
#  {'taxid': 30522,
#   'rsid': 11922196,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Mammalia',
#   'order': 'Artiodactyla',
#   'species': 'Bos indicus x Bos taurus'},
#  {'taxid': 43346,
#   'rsid': 19954,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Mammalia',
#   'order': 'Artiodactyla',
#   'species': 'Bison bison'},
#  {'taxid': 9902,
#   'rsid': 12480,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Mammalia',
#   'order': 'Artiodactyla',
#   'species': 'Bison bonasus'},
#  {'taxid': 7227,
#   'rsid': 5617551,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Insecta',
#   'order': 'Diptera',
#   'species': 'Drosophila melanogaster'},
#  {'taxid': 4232,
#   'rsid': 42533,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Viridiplantae',
#   'class': 'Magnoliopsida',
#   'order': 'Asterales',
#   'species': 'Helianthus annuus'},
#  {'taxid': 61171,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Erysipelotrichia',
#   'order': 'Erysipelotrichales',
#   'species': 'Holdemania filiformis'},
#  {'taxid': 281920,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Bacteroidia',
#   'order': 'Bacteroidales',
#   'species': 'Porphyromonas uenonis'},
#  {'taxid': 1685,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Actinomycetes',
#   'order': 'Bifidobacteriales',
#   'species': 'Bifidobacterium breve'},
#  {'taxid': 4555,
#   'rsid': 4680961,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Viridiplantae',
#   'class': 'Magnoliopsida',
#   'order': 'Poales',
#   'species': 'Setaria italica'},
#  {'taxid': 901,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Deltaproteobacteria',
#   'order': 'Desulfovibrionales',
#   'species': 'Desulfovibrio piger'},
#  {'taxid': 34690,
#   'rsid': 5945705,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Insecta',
#   'order': 'Diptera',
#   'species': 'Anopheles melas'},
#  {'taxid': 283035,
#   'rsid': 975373,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Actinopteri',
#   'order': 'Perciformes',
#   'species': 'Sander lucioperca'},
#  {'taxid': 169435,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Clostridia',
#   'order': 'Eubacteriales',
#   'species': 'Anaerotruncus colihominis'},
#  {'taxid': 1351,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Bacilli',
#   'order': 'Lactobacillales',
#   'species': 'Enterococcus faecalis'},
#  {'taxid': 905,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Negativicutes',
#   'order': 'Acidaminococcales',
#   'species': 'Acidaminococcus fermentans'},
#  {'taxid': 51240,
#   'rsid': 142372,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Viridiplantae',
#   'class': 'Magnoliopsida',
#   'order': 'Fagales',
#   'species': 'Juglans regia'},
#  {'taxid': 147206,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Coriobacteriia',
#   'order': 'Coriobacteriales',
#   'species': 'Collinsella stercoris'},
#  {'taxid': 384638,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Clostridia',
#   'order': 'Eubacteriales',
#   'species': '[Bacteroides] pectinophilus'},
#  {'taxid': 8018,
#   'rsid': 0,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Actinopteri',
#   'order': 'Salmoniformes',
#   'species': 'Oncorhynchus keta'},
#  {'taxid': 333367,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Clostridia',
#   'order': 'Eubacteriales',
#   'species': 'Enterocloster asparagiformis'},
#  {'taxid': 9615,
#   'rsid': 46934776,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Mammalia',
#   'order': 'Carnivora',
#   'species': 'Canis lupus'},
#  {'taxid': 411489,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Clostridia',
#   'order': 'Eubacteriales',
#   'species': 'Clostridium sp. L2-50'},
#  {'taxid': 85692,
#   'rsid': 1755050,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Viridiplantae',
#   'class': 'Magnoliopsida',
#   'order': 'Poales',
#   'species': 'Triticum dicoccoides'},
#  {'taxid': 52644,
#   'rsid': 43596,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Aves',
#   'order': 'Accipitriformes',
#   'species': 'Haliaeetus leucocephalus'},
#  {'taxid': 9923,
#   'rsid': 17161532,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Mammalia',
#   'order': 'Artiodactyla',
#   'species': 'Capra aegagrus'},
#  {'taxid': 215358,
#   'rsid': 1492,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Actinopteri',
#   'order': 'Actinopteri',
#   'species': 'Larimichthys crocea'},
#  {'taxid': 45851,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Clostridia',
#   'order': 'Eubacteriales',
#   'species': 'Butyrivibrio crossotus'},
#  {'taxid': 31971,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Erysipelotrichia',
#   'order': 'Erysipelotrichales',
#   'species': 'Amedibacillus dolichus'},
#  {'taxid': 28025,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Actinomycetes',
#   'order': 'Bifidobacteriales',
#   'species': 'Bifidobacterium animalis'},
#  {'taxid': 13489,
#   'rsid': 37125,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Actinopteri',
#   'order': 'Actinopteri',
#   'species': 'Dicentrarchus labrax'},
#  {'taxid': 9627,
#   'rsid': 7,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Mammalia',
#   'order': 'Carnivora',
#   'species': 'Vulpes vulpes'},
#  {'taxid': 116085,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Clostridia',
#   'order': 'Eubacteriales',
#   'species': 'Coprococcus catus'},
#  {'taxid': 6183,
#   'rsid': 0,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Trematoda',
#   'order': 'Strigeidida',
#   'species': 'Schistosoma mansoni'},
#  {'taxid': 7950,
#   'rsid': 0,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Actinopteri',
#   'order': 'Clupeiformes',
#   'species': 'Clupea harengus'},
#  {'taxid': 51953,
#   'rsid': 52383,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Viridiplantae',
#   'class': 'Magnoliopsida',
#   'order': 'Arecales',
#   'species': 'Elaeis guineensis'},
#  {'taxid': 1679538,
#   'rsid': 1436,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Viridiplantae',
#   'class': 'Magnoliopsida',
#   'order': 'Arecales',
#   'species': 'Elaeis oleifera x Elaeis guineensis'},
#  {'taxid': 470,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Gammaproteobacteria',
#   'order': 'Moraxellales',
#   'species': 'Acinetobacter baumannii'},
#  {'taxid': 7165,
#   'rsid': 1211783,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Insecta',
#   'order': 'Diptera',
#   'species': 'Anopheles gambiae'},
#  {'taxid': 28111,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Bacteroidia',
#   'order': 'Bacteroidales',
#   'species': 'Bacteroides eggerthii'},
#  {'taxid': 39491,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Clostridia',
#   'order': 'Eubacteriales',
#   'species': '[Eubacterium] rectale'},
#  {'taxid': 6238,
#   'rsid': 0,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Chromadorea',
#   'order': 'Rhabditida',
#   'species': 'Caenorhabditis briggsae'},
#  {'taxid': 1308,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Bacilli',
#   'order': 'Lactobacillales',
#   'species': 'Streptococcus thermophilus'},
#  {'taxid': 239935,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Verrucomicrobiae',
#   'order': 'Verrucomicrobiales',
#   'species': 'Akkermansia muciniphila'},
#  {'taxid': 1735,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Erysipelotrichia',
#   'order': 'Erysipelotrichales',
#   'species': 'Holdemanella biformis'},
#  {'taxid': 147207,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Coriobacteriia',
#   'order': 'Coriobacteriales',
#   'species': 'Collinsella intestinalis'},
#  {'taxid': 3712,
#   'rsid': 625798,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Viridiplantae',
#   'class': 'Magnoliopsida',
#   'order': 'Brassicales',
#   'species': 'Brassica oleracea'},
#  {'taxid': 5476,
#   'rsid': 0,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Fungi',
#   'class': 'Saccharomycetes',
#   'order': 'Saccharomycetales',
#   'species': 'Candida albicans'},
#  {'taxid': 4679,
#   'rsid': 0,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Viridiplantae',
#   'class': 'Magnoliopsida',
#   'order': 'Asparagales',
#   'species': 'Allium cepa'},
#  {'taxid': 1598,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Bacilli',
#   'order': 'Lactobacillales',
#   'species': 'Limosilactobacillus reuteri'},
#  {'taxid': 39485,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Clostridia',
#   'order': 'Eubacteriales',
#   'species': 'Lachnospira eligens'},
#  {'taxid': 2697049,
#   'rsid': 56818,
#   'superkingdom': 'Viruses',
#   'kingdom': 'Orthornavirae',
#   'class': 'Pisoniviricetes',
#   'order': 'Nidovirales',
#   'species': 'Severe acute respiratory syndrome-related coronavirus'},
#  {'taxid': 216498,
#   'rsid': 0,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Polychaeta',
#   'order': 'Sabellida',
#   'species': 'Hydroides elegans'},
#  {'taxid': 52226,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Negativicutes',
#   'order': 'Selenomonadales',
#   'species': 'Mitsuokella multacida'},
#  {'taxid': 3330,
#   'rsid': 0,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Viridiplantae',
#   'class': 'Pinopsida',
#   'order': 'Pinales',
#   'species': 'Picea glauca'},
#  {'taxid': 110835,
#   'rsid': 7682,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Viridiplantae',
#   'class': 'Magnoliopsida',
#   'order': 'Poales',
#   'species': 'Eragrostis tef'},
#  {'taxid': 1358,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Bacilli',
#   'order': 'Lactobacillales',
#   'species': 'Lactococcus lactis'},
#  {'taxid': 29466,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Negativicutes',
#   'order': 'Veillonellales',
#   'species': 'Veillonella parvula'},
#  {'taxid': 1322,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Clostridia',
#   'order': 'Eubacteriales',
#   'species': 'Blautia hansenii'},
#  {'taxid': 13616,
#   'rsid': 0,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Mammalia',
#   'order': 'Didelphimorphia',
#   'species': 'Monodelphis domestica'},
#  {'taxid': 3750,
#   'rsid': 227590,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Viridiplantae',
#   'class': 'Magnoliopsida',
#   'order': 'Rosales',
#   'species': 'Malus domestica'},
#  {'taxid': 28901,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Gammaproteobacteria',
#   'order': 'Enterobacterales',
#   'species': 'Salmonella enterica'},
#  {'taxid': 46503,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Bacteroidia',
#   'order': 'Bacteroidales',
#   'species': 'Parabacteroides merdae'},
#  {'taxid': 8019,
#   'rsid': 0,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Actinopteri',
#   'order': 'Salmoniformes',
#   'species': 'Oncorhynchus kisutch'},
#  {'taxid': 472,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Gammaproteobacteria',
#   'order': 'Moraxellales',
#   'species': 'Acinetobacter sp.'},
#  {'taxid': 9601,
#   'rsid': 9831260,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Mammalia',
#   'order': 'Primates',
#   'species': 'Pongo abelii'},
#  {'taxid': 457412,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Clostridia',
#   'order': 'Eubacteriales',
#   'species': 'Ruminococcus sp. 5_1_39BFAA'},
#  {'taxid': 10141,
#   'rsid': 819330,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Mammalia',
#   'order': 'Rodentia',
#   'species': 'Cavia porcellus'},
#  {'taxid': 9685,
#   'rsid': 3420288,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Mammalia',
#   'order': 'Carnivora',
#   'species': 'Felis catus'},
#  {'taxid': 33038,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Clostridia',
#   'order': 'Eubacteriales',
#   'species': '[Ruminococcus] gnavus'},
#  {'taxid': 52132,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Alphaproteobacteria',
#   'order': 'Hyphomicrobiales',
#   'species': 'Brucella sp.'},
#  {'taxid': 165179,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Bacteroidia',
#   'order': 'Bacteroidales',
#   'species': 'Prevotella copri'},
#  {'taxid': 9823,
#   'rsid': 71862418,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Mammalia',
#   'order': 'Artiodactyla',
#   'species': 'Sus scrofa'},
#  {'taxid': 387090,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Bacteroidia',
#   'order': 'Bacteroidales',
#   'species': 'Phocaeicola coprophilus'},
#  {'taxid': 218538,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Negativicutes',
#   'order': 'Veillonellales',
#   'species': 'Dialister invisus'},
#  {'taxid': 71647,
#   'rsid': 0,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Viridiplantae',
#   'class': 'Pinopsida',
#   'order': 'Pinales',
#   'species': 'Pinus pinaster'},
#  {'taxid': 9807,
#   'rsid': 0,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Mammalia',
#   'order': 'Perissodactyla',
#   'species': 'Ceratotherium simum'},
#  {'taxid': 556270,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Erysipelotrichia',
#   'order': 'Erysipelotrichales',
#   'species': 'Coprobacillus sp. D7'},
#  {'taxid': 202950,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Gammaproteobacteria',
#   'order': 'Moraxellales',
#   'species': 'Acinetobacter baylyi'},
#  {'taxid': 8237,
#   'rsid': 0,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Actinopteri',
#   'order': 'Scombriformes',
#   'species': 'Thunnus thynnus'},
#  {'taxid': 7175,
#   'rsid': 0,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Insecta',
#   'order': 'Diptera',
#   'species': 'Culex pipiens'},
#  {'taxid': 3711,
#   'rsid': 164,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Viridiplantae',
#   'class': 'Magnoliopsida',
#   'order': 'Brassicales',
#   'species': 'Brassica rapa'},
#  {'taxid': 1255,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Bacilli',
#   'order': 'Lactobacillales',
#   'species': 'Pediococcus pentosaceus'},
#  {'taxid': 452646,
#   'rsid': 34816,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Mammalia',
#   'order': 'Carnivora',
#   'species': 'Neogale vison'},
#  {'taxid': 469587,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Bacteroidia',
#   'order': 'Bacteroidales',
#   'species': 'Bacteroides fragilis'},
#  {'taxid': 39492,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Clostridia',
#   'order': 'Eubacteriales',
#   'species': '[Eubacterium] siraeum'},
#  {'taxid': 30521,
#   'rsid': 30623660,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Mammalia',
#   'order': 'Artiodactyla',
#   'species': 'Bos grunniens'},
#  {'taxid': 9940,
#   'rsid': 94024533,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Mammalia',
#   'order': 'Artiodactyla',
#   'species': 'Ovis aries'},
#  {'taxid': 60711,
#   'rsid': 66435157,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Mammalia',
#   'order': 'Primates',
#   'species': 'Chlorocebus sabaeus'},
#  {'taxid': 665079,
#   'rsid': 1937,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Fungi',
#   'class': 'Leotiomycetes',
#   'order': 'Helotiales',
#   'species': 'Sclerotinia sclerotiorum'},
#  {'taxid': 7460,
#   'rsid': 19401713,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Insecta',
#   'order': 'Hymenoptera',
#   'species': 'Apis mellifera'},
#  {'taxid': 8023,
#   'rsid': 0,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Actinopteri',
#   'order': 'Salmoniformes',
#   'species': 'Oncorhynchus nerka'},
#  {'taxid': 27828,
#   'rsid': 0,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Chromadorea',
#   'order': 'Strongylida',
#   'species': 'Cooperia oncophora'},
#  {'taxid': 84112,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Coriobacteriia',
#   'order': 'Eggerthellales',
#   'species': 'Eggerthella lenta'},
#  {'taxid': 1161942,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Clostridia',
#   'order': 'Eubacteriales',
#   'species': 'Ruminococcus champanellensis'},
#  {'taxid': 53443,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Clostridia',
#   'order': 'Eubacteriales',
#   'species': 'Blautia hydrogenotrophica'},
#  {'taxid': 7955,
#   'rsid': 19134427,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Actinopteri',
#   'order': 'Cypriniformes',
#   'species': 'Danio rerio'},
#  {'taxid': 411484,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Clostridia',
#   'order': 'Eubacteriales',
#   'species': 'Clostridium sp. SS2/1'},
#  {'taxid': 158847,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Negativicutes',
#   'order': 'Selenomonadales',
#   'species': 'Megamonas hypermegale'},
#  {'taxid': 1680,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Actinomycetes',
#   'order': 'Bifidobacteriales',
#   'species': 'Bifidobacterium adolescentis'},
#  {'taxid': 28037,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Bacilli',
#   'order': 'Lactobacillales',
#   'species': 'Streptococcus mitis'},
#  {'taxid': 7425,
#   'rsid': 205691,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Insecta',
#   'order': 'Hymenoptera',
#   'species': 'Nasonia vitripennis'},
#  {'taxid': 9598,
#   'rsid': 22802408,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Mammalia',
#   'order': 'Primates',
#   'species': 'Pan troglodytes'},
#  {'taxid': 48296,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Gammaproteobacteria',
#   'order': 'Moraxellales',
#   'species': 'Acinetobacter pittii'},
#  {'taxid': 33039,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Clostridia',
#   'order': 'Eubacteriales',
#   'species': '[Ruminococcus] torques'},
#  {'taxid': 41447,
#   'rsid': 8422148,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Actinopteri',
#   'order': 'Carangiformes',
#   'species': 'Seriola dumerili'},
#  {'taxid': 3702,
#   'rsid': 26323477,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Viridiplantae',
#   'class': 'Magnoliopsida',
#   'order': 'Brassicales',
#   'species': 'Arabidopsis thaliana'},
#  {'taxid': 410072,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Clostridia',
#   'order': 'Eubacteriales',
#   'species': 'Coprococcus comes'},
#  {'taxid': 39483,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Erysipelotrichia',
#   'order': 'Erysipelotrichales',
#   'species': 'Faecalitalea cylindroides'},
#  {'taxid': 39488,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Clostridia',
#   'order': 'Eubacteriales',
#   'species': 'Anaerobutyricum hallii'},
#  {'taxid': 46228,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Clostridia',
#   'order': 'Eubacteriales',
#   'species': '[Ruminococcus] lactaris'},
#  {'taxid': 469796,
#   'rsid': 29141833,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Mammalia',
#   'order': 'Artiodactyla',
#   'species': 'Ovis orientalis'},
#  {'taxid': 72761,
#   'rsid': 2541,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Mammalia',
#   'order': 'Artiodactyla',
#   'species': 'Ovis dalli'},
#  {'taxid': 28117,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Bacteroidia',
#   'order': 'Bacteroidales',
#   'species': 'Alistipes putredinis'},
#  {'taxid': 28116,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Bacteroidia',
#   'order': 'Bacteroidales',
#   'species': 'Bacteroides ovatus'},
#  {'taxid': 84645,
#   'rsid': 2397236,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Actinopteri',
#   'order': 'Cypriniformes',
#   'species': 'Labeo rohita'},
#  {'taxid': 1261,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Clostridia',
#   'order': 'Eubacteriales',
#   'species': 'Peptostreptococcus anaerobius'},
#  {'taxid': 471,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Gammaproteobacteria',
#   'order': 'Moraxellales',
#   'species': 'Acinetobacter calcoaceticus'},
#  {'taxid': 7159,
#   'rsid': 25589,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Insecta',
#   'order': 'Diptera',
#   'species': 'Aedes aegypti'},
#  {'taxid': 4615,
#   'rsid': 14644,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Viridiplantae',
#   'class': 'Magnoliopsida',
#   'order': 'Poales',
#   'species': 'Ananas comosus'},
#  {'taxid': 48849,
#   'rsid': 0,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Aves',
#   'order': 'Passeriformes',
#   'species': 'Passer domesticus'},
#  {'taxid': 3625,
#   'rsid': 5,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Viridiplantae',
#   'class': 'Magnoliopsida',
#   'order': 'Ericales',
#   'species': 'Actinidia chinensis'},
#  {'taxid': 154046,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Clostridia',
#   'order': 'Eubacteriales',
#   'species': 'Hungatella hathewayi'},
#  {'taxid': 9600,
#   'rsid': 0,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Mammalia',
#   'order': 'Primates',
#   'species': 'Pongo pygmaeus'},
#  {'taxid': 1535,
#   'rsid': 0,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Clostridia',
#   'order': 'Eubacteriales',
#   'species': '[Clostridium] leptum'},
#  {'taxid': 2020318,
#   'rsid': 3524,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Aves',
#   'order': 'Passeriformes',
#   'species': 'Anthochaera phrygia'},
#  {'taxid': 201502,
#   'rsid': 96808,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Insecta',
#   'order': 'Diptera',
#   'species': 'Glossina fuscipes'},
#  {'taxid': 9078,
#   'rsid': 7735366,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Aves',
#   'order': 'Galliformes',
#   'species': 'Alectoris chukar'},
#  {'taxid': 6131,
#   'rsid': 13236,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Anthozoa',
#   'order': 'Scleractinia',
#   'species': 'Acropora palmata'},
#  {'taxid': 4513,
#   'rsid': 178702333,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Viridiplantae',
#   'class': 'Magnoliopsida',
#   'order': 'Poales',
#   'species': 'Hordeum vulgare'},
#  {'taxid': 217634,
#   'rsid': 329566,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Insecta',
#   'order': 'Coleoptera',
#   'species': 'Anoplophora glabripennis'},
#  {'taxid': 3917,
#   'rsid': 17,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Viridiplantae',
#   'class': 'Magnoliopsida',
#   'order': 'Fabales',
#   'species': 'Vigna unguiculata'},
#  {'taxid': 1010633,
#   'rsid': 11046501,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Viridiplantae',
#   'class': 'Magnoliopsida',
#   'order': 'Poales',
#   'species': 'Digitaria exilis'},
#  {'taxid': 158451,
#   'rsid': 10774468,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Actinopteri',
#   'order': 'Anabantiformes',
#   'species': 'Macropodus opercularis'},
#  {'taxid': 199890,
#   'rsid': 42,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Insecta',
#   'order': 'Diptera',
#   'species': 'Anopheles epiroticus'},
#  {'taxid': 4932,
#   'rsid': 83916,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Fungi',
#   'class': 'Saccharomycetes',
#   'order': 'Saccharomycetales',
#   'species': 'Saccharomyces cerevisiae'},
#  {'taxid': 4550,
#   'rsid': 2872137,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Viridiplantae',
#   'class': 'Magnoliopsida',
#   'order': 'Poales',
#   'species': 'Secale cereale'},
#  {'taxid': 1770,
#   'rsid': 65988,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Actinomycetes',
#   'order': 'Corynebacteriales',
#   'species': 'Mycobacterium avium'},
#  {'taxid': 34324,
#   'rsid': 6226072,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Viridiplantae',
#   'class': 'Magnoliopsida',
#   'order': 'Myrtales',
#   'species': 'Corymbia calophylla'},
#  {'taxid': 3329,
#   'rsid': 4715,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Viridiplantae',
#   'class': 'Pinopsida',
#   'order': 'Pinales',
#   'species': 'Picea abies'},
#  {'taxid': 169963,
#   'rsid': 29,
#   'superkingdom': 'Bacteria',
#   'kingdom': 'Bacteria',
#   'class': 'Bacilli',
#   'order': 'Bacillales',
#   'species': 'Listeria monocytogenes'},
#  {'taxid': 9447,
#   'rsid': 124991,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Mammalia',
#   'order': 'Primates',
#   'species': 'Lemur catta'},
#  {'taxid': 869827,
#   'rsid': 411144,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Viridiplantae',
#   'class': 'Magnoliopsida',
#   'order': 'Cucurbitales',
#   'species': 'Cucumis sativus'},
#  {'taxid': 4097,
#   'rsid': 55105,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Viridiplantae',
#   'class': 'Magnoliopsida',
#   'order': 'Solanales',
#   'species': 'Nicotiana tabacum'},
#  {'taxid': 7173,
#   'rsid': 149,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Insecta',
#   'order': 'Diptera',
#   'species': 'Anopheles arabiensis'},
#  {'taxid': 1089451,
#   'rsid': 11374,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Fungi',
#   'class': 'Sordariomycetes',
#   'order': 'Hypocreales',
#   'species': 'Fusarium odoratissimum'},
#  {'taxid': 112509,
#   'rsid': 29207,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Viridiplantae',
#   'class': 'Magnoliopsida',
#   'order': 'Poales',
#   'species': 'Hordeum vulgare'},
#  {'taxid': 415032,
#   'rsid': 123966,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Aves',
#   'order': 'Passeriformes',
#   'species': 'Pseudopipra pipra'},
#  {'taxid': 9103,
#   'rsid': 5824,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Aves',
#   'order': 'Galliformes',
#   'species': 'Meleagris gallopavo'},
#  {'taxid': 69109,
#   'rsid': 124,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Viridiplantae',
#   'class': 'Magnoliopsida',
#   'order': 'Malvales',
#   'species': 'Adansonia digitata'},
#  {'taxid': 38873,
#   'rsid': 5363530,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Viridiplantae',
#   'class': 'Magnoliopsida',
#   'order': 'Lamiales',
#   'species': 'Fraxinus excelsior'},
#  {'taxid': 230844,
#   'rsid': 79830114,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Mammalia',
#   'order': 'Rodentia',
#   'species': 'Peromyscus maniculatus'},
#  {'taxid': 69004,
#   'rsid': 9360457,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Insecta',
#   'order': 'Diptera',
#   'species': 'Anopheles farauti'},
#  {'taxid': 44689,
#   'rsid': 107706,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Eukaryota',
#   'class': 'Eumycetozoa',
#   'order': 'Dictyosteliales',
#   'species': 'Dictyostelium discoideum'},
#  {'taxid': 89462,
#   'rsid': 4,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Mammalia',
#   'order': 'Artiodactyla',
#   'species': 'Bubalus bubalis'},
#  {'taxid': 1862899,
#   'rsid': 45190776,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Insecta',
#   'order': 'Diptera',
#   'species': 'Ceratitis quilicii'},
#  {'taxid': 3641,
#   'rsid': 12881572,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Viridiplantae',
#   'class': 'Magnoliopsida',
#   'order': 'Malvales',
#   'species': 'Theobroma cacao'},
#  {'taxid': 9716,
#   'rsid': 1470850,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Metazoa',
#   'class': 'Mammalia',
#   'order': 'Carnivora',
#   'species': 'Mirounga angustirostris'},
#  {'taxid': 3663,
#   'rsid': 3880961,
#   'superkingdom': 'Eukaryota',
#   'kingdom': 'Viridiplantae',
#   'class': 'Magnoliopsida',
#   'order': 'Cucurbitales',
#   'species': 'Cucurbita pepo'}]

# %%
df = pd.DataFrame.from_dict(release_records)
df['label'] = df['class']
df.loc[df.superkingdom != 'Eukaryota', 'label'] = 'Others'

# Change all the label not in the list bellow to others
accepted_classes = {'Aves': 'Birds','Insecta':'Insects','Actinopteri': 'Fish','Mammalia': 'Mammals','Magnoliopsida': 'Flowering plants', 'Non-Eukaryota': 'Non-Eukaryotes', 'Homo sapiens': 'Human'}
# Check ~ which somehow means "NOT IN" in pandas
df.loc[~df['label'].isin(accepted_classes), 'label'] = 'Others'
df = df.replace({'label': accepted_classes})

# Change the label of Human to separate them from other mammals
df.loc[df.species == 'Homo sapiens', 'label'] = 'Human'
# df = df[df.label != 'Others']
# df = df[df.label != 'Human']

data = df.groupby(['label'])[['rsid']].sum().sort_values(by='rsid').reset_index()
seaborn.set_style("whitegrid") # Set style for chart
plt.figure(figsize=(6,6)) # Set figure size
plt.pie(data['rsid'], labels=data['label'], autopct='%1.0f%%',  pctdistance=.8, textprops={'fontsize': 20}) # Create pie chart
# plt.pie(sizes, labels=sizes.index, autopct='%1.0f%%',  pctdistance=.8, textprops={'fontsize': 20}) # Create pie chart
plt.show() # Show chart

# %%
df2 = df[df['rsid'] > 10000000]
seaborn.catplot(df2, kind="bar", x='species', y='rsid', hue='label')
